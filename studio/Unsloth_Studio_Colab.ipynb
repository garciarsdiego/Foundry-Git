# %% [markdown]
# <a href="https://colab.research.google.com/github/garciarsdiego/Foundry-GitLegacy/blob/main/studio/Unsloth_Studio_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth Studio on your local device, follow [our guide](https://unsloth.ai/docs/new/unsloth-studio/install). Unsloth Studio is licensed [AGPL-3.0](https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0).
#
# ### Unsloth Studio
#
# Train and run open models with [**Unsloth Studio**](https://unsloth.ai/docs/new/unsloth-studio/start). NEW! Installation should now only take 2 mins!
#
#
# We are actively working on making Unsloth Studio install on Colab T4 GPUs faster.
#
# [Features](https://unsloth.ai/docs/new/unsloth-studio#features) • [Quickstart](https://unsloth.ai/docs/new/unsloth-studio/start) • [Data Recipes](https://unsloth.ai/docs/new/unsloth-studio/data-recipe) • [Studio Chat](https://unsloth.ai/docs/new/unsloth-studio/chat) • [Export](https://unsloth.ai/docs/new/unsloth-studio/export)

# %% [markdown]
# <p align="left"><img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/studio%20github%20landscape%20colab%20display.png" width="600"></p>

# %% [markdown]
# ### Setup: Clone repo and run setup

# %%
# !git clone --depth 1 --branch main https://github.com/unslothai/unsloth.git
# %cd /content/unsloth
# !chmod +x studio/setup.sh && ./studio/setup.sh --local

# %% [markdown]
# ### Start Unsloth Studio

# %%
import sys, time
sys.path.insert(0, "/content/unsloth/studio/backend")
from colab import start
start()

# %%
from google.colab import output
output.serve_kernel_port_as_iframe(8888, height = 1200, width = "100%")
for _ in range(10000): time.sleep(300), print("=", end = "")
# Out:
# {"timestamp": "2026-05-14T00:13:20.979774Z", "level": "info", "event": "Helper GGUF cached: 1 file(s)"}
# {"timestamp": "2026-05-14T00:13:21.179815Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 1.09}
# {"timestamp": "2026-05-14T00:13:50.865891Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 0.81}
# {"timestamp": "2026-05-14T00:13:52.714854Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 0.64}
# {"timestamp": "2026-05-14T00:13:53.213847Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.08}
# {"timestamp": "2026-05-14T00:13:53.412134Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 0.83}
# {"timestamp": "2026-05-14T00:13:53.915036Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 0.74}
# {"timestamp": "2026-05-14T00:13:59.951683Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/login", "status_code": 200, "process_time_ms": 26.47}
# {"timestamp": "2026-05-14T00:14:00.190558Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/change-password", "status_code": 200, "process_time_ms": 54.56}
# {"timestamp": "2026-05-14T00:14:00.408153Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 0.65}
# {"timestamp": "2026-05-14T00:14:00.588294Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 0.68}
# {"timestamp": "2026-05-14T00:14:00.768457Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 0.87}
# {"timestamp": "2026-05-14T00:14:00.823557Z", "level": "info", "event": "InferenceOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-05-14T00:14:00.824608Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 2.89}
# {"timestamp": "2026-05-14T00:14:01.077817Z", "level": "info", "event": "Top GGUF models: ['unsloth/gemma-4-26B-A4B-it-GGUF', 'unsloth/Qwen3.6-35B-A3B-GGUF', 'unsloth/Qwen3.6-27B-GGUF', 'unsloth/gemma-4-31B-it-GGUF', 'unsloth/gemma-4-E4B-it-GGUF', 'unsloth/Qwen3.5-9B-GGUF', 'unsloth/gemma-4-E2B-it-GGUF', 'unsloth/Qwen3.5-35B-A3B-GGUF', 'unsloth/Qwen3.5-4B-GGUF', 'unsloth/Qwen3-Coder-Next-GGUF', 'unsloth/Qwen3-30B-A3B-Instruct-2507-GGUF', 'unsloth/Qwen3.5-27B-GGUF', 'unsloth/Qwen3.5-0.8B
z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.08}
# {"timestamp": "2026-05-14T00:16:23.600924Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.06}
# {"timestamp": "2026-05-14T00:16:25.600999Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.07}
# {"timestamp": "2026-05-14T00:16:27.611007Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.05}
# {"timestamp": "2026-05-14T00:16:29.623545Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.23}
# {"timestamp": "2026-05-14T00:16:31.602176Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.05}
# {"timestamp": "2026-05-14T00:16:33.598173Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.03}
# {"timestamp": "2026-05-14T00:16:35.594054Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.04}
# {"timestamp": "2026-05-14T00:16:37.621069Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.04}
# {"timestamp": "2026-05-14T00:16:39.595609Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.06}
# {"timestamp": "2026-05-14T00:16:41.596474Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.12}
# {"timestamp": "2026-05-14T00:16:43.592897Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.09}
# {"timestamp": "2026-05-14T00:16:45.417078Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.02}
# {"timestamp": "2026-05-14T00:16:47.158426Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.05}
# {"timestamp": "2026-05-14T00:16:49.138846Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.09}
# {"timestamp": "2026-05-14T00:16:51.611530Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.07}
# {"timestamp": "2026-05-14T00:16:53.592672Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.08}
# {"timestamp": "2026-05-14T00:16:55.591987Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.06}
# {"timestamp": "2026-05-14T00:16:57.414618Z", "level": "info", "event": "GGUF downloaded in 77.4s: /root/.cache/huggingface/hub/models--unsloth--Qwen3.6-35B-A3B-GGUF/snapshots/a483e9e6cbd595906af30beda3187c2663a1118c/Qwen3.6-35B-A3B-UD-Q5_K_XL.gguf"}
# {"timestamp": "2026-05-14T00:16:57.512015Z", "level": "info", "event": "Downloading mmproj: unsloth/Qwen3.6-35B-A3B-GGUF/mmproj-F16.gguf"}
# {"timestamp": "2026-05-14T00:16:57.608890Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.24}
# mmproj-F16.gguf:   0%|          | 0.00/899M [00:00<?, ?B/s]
# {"timestamp": "2026-05-14T00:16:59.604948Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/load-progress", "status_code": 200, "process_time_ms": 0.98}
# {"timestamp": "2026-05-14T00:17:00.752813Z", "level": "info", "event": "GGUF metadata: context_length=262144"}
# {"timestamp": "2026-05-14T00:17:00.753041Z", "level": "info", "event": "GGUF metadata: chat_template=8057 chars"}
# {"timestamp": "2026-05-14T00:17:00.753199Z", "level": "info", "event": "GGUF metadata: model supports reasoning (enable_thinking)"}
# {"timestamp": "2026-05-14T00:17:00.753340Z", "level": "info", "event": "GGUF metadata: model supports preserve_thinking"}
# {"timestamp": "2026-05-14T00:17:00.753495Z", "level": "info", "event": "GGUF metadata: model supports tool calling"}
# {"timestamp": "2026-05-14T00:17:00.766394Z", "level": "info", "event": "GGUF size: 24.8 GB, est. KV cache: 5.0 GB, context: 262144, GPUs free: [(0, 97248)], selected: [0], fit: False"}
# {"timestamp": "2026-05-14T00:17:00.766693Z", "level": "info", "event": "Reasoning model: {'enable_thinking': False} by default"}
# {"timestamp": "2026-05-14T00:17:00.766958Z", "level": "info", "event": "Using mmproj for vision: /root/.cache/huggingface/hub/models--unsloth--Qwen3.6-35B-A3B-GGUF/snapshots/a483e9e6cbd595906af30beda3187c2663a1118c/mmproj-F16.gguf"}
# {"timestamp": "2026-05-14T00:17:00.767186Z", "level": "info", "event": "Starting llama-server: /root/.unsloth/llama.cpp/llama-server -m /root/.cache/huggingface/hub/models--unsloth--Qwen3.6-35B-A3B-GGUF/snapshots/a483e9e6cbd595906af30beda3187c2663a1118c/Qwen3.6-35B-A3B-UD-Q5_K_XL.gguf --port 53353 -c 262144 --parallel 1 --flash-attn on --no-context-shift -ngl -1 --threads -1 --jinja --chat-template-kwargs {\"enable_thinking\": false} --mmproj /root/.cache/huggingface/hub/models--unsloth--Qwen3.6-35B-A3B-GGUF/snapshots/a483e9e6cbd595906af30beda3187c2663a1118c/mmproj-F16.gguf"}
# {"timestamp": "2026-05-14T00:17:01.619978Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/load-progress", "status_code": 200, "process_time_ms": 0.9}
# {"timestamp": "2026-05-14T00:17:03.139731Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/load-progress", "status_code": 200, "process_time_ms": 0.94}
# {"timestamp": "2026-05-14T00:17:04.270831Z", "level": "info", "event": "llama-server ready on port 53353 for model 'unsloth/Qwen3.6-35B-A3B-GGUF'"}
# {"timestamp": "2026-05-14T00:17:04.271437Z", "level": "info", "event": "Loaded GGUF model via llama-server: unsloth/Qwen3.6-35B-A3B-GGUF"}
# {"timestamp": "2026-05-14T00:17:04.294585Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-05-14T00:17:04.297183Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/load", "status_code": 200, "process_time_ms": 84696.4}
# {"timestamp": "2026-05-14T00:17:04.504287Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 2.08}
# {"timestamp": "2026-05-14T00:17:04.506742Z", "level": "info", "event": "Found 0 trained models in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-05-14T00:17:04.507065Z", "level": "info", "event": "Found 0 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-05-14T00:17:04.507387Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 1.62}
# {"timestamp": "2026-05-14T00:17:04.510219Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-05-14T00:17:04.512170Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 4.22}
# ={"timestamp": "2026-05-14T00:19:56.003072Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/v1/chat/completions", "status_code": 200, "process_time_ms": 13.23}
# {"timestamp": "2026-05-14T00:22:22.038011Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/v1/chat/completions", "status_code": 200, "process_time_ms": 1.26}
# ={"timestamp": "2026-05-14T00:24:49.923600Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/recommended-folders", "status_code": 200, "process_time_ms": 1.49}
# {"timestamp": "2026-05-14T00:24:49.927160Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 3.67}
# {"timestamp": "2026-05-14T00:24:49.927453Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-gguf", "status_code": 200, "process_time_ms": 3.94}
# {"timestamp": "2026-05-14T00:24:49.927635Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/scan-folders", "status_code": 200, "process_time_ms": 4.1}
# {"timestamp": "2026-05-14T00:24:49.929222Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-models", "status_code": 200, "process_time_ms": 1.38}
# {"timestamp": "2026-05-14T00:24:52.566982Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-variants", "status_code": 200, "process_time_ms": 180.45}
# {"timestamp": "2026-05-14T00:24:55.722536Z", "level": "info", "event": "request_completed", "method": "DELETE", "path": "/api/models/delete-cached", "status_code": 400, "process_time_ms": 1.43}
# {"timestamp": "2026-05-14T00:25:00.127188Z", "level": "info", "event": "Unloaded GGUF model: unsloth/Qwen3.6-35B-A3B-GGUF"}
# {"timestamp": "2026-05-14T00:25:00.127597Z", "level": "info", "event": "Unloaded GGUF model: unsloth/Qwen3.6-35B-A3B-GGUF"}
# {"timestamp": "2026-05-14T00:25:00.127942Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/unload", "status_code": 200, "process_time_ms": 215.63}
# {"timestamp": "2026-05-14T00:25:00.256824Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 1.48}
# {"timestamp": "2026-05-14T00:25:00.261375Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/scan-folders", "status_code": 200, "process_time_ms": 0.73}
# {"timestamp": "2026-05-14T00:25:00.264376Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-models", "status_code": 200, "process_time_ms": 1.36}
# {"timestamp": "2026-05-14T00:25:00.266644Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/recommended-folders", "status_code": 200, "process_time_ms": 0.62}
# {"timestamp": "2026-05-14T00:25:00.270494Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-gguf", "status_code": 200, "process_time_ms": 1.38}
# {"timestamp": "2026-05-14T00:25:00.325884Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 1.76}
# {"timestamp": "2026-05-14T00:25:00.327061Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 0.56}
# {"timestamp": "2026-05-14T00:25:00.328868Z", "level": "info", "event": "Found 0 trained models in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-05-14T00:25:00.329196Z", "level": "info", "event": "Found 0 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-05-14T00:25:00.329461Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 1.27}
# {"timestamp": "2026-05-14T00:25:01.161368Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-variants", "status_code": 200, "process_time_ms": 112.25}
# {"timestamp": "2026-05-14T00:25:05.820044Z", "level": "info", "event": "Deleted 1 file(s) for unsloth/Qwen3.6-35B-A3B-GGUF variant UD-Q5_K_XL: 25360.6 MB freed"}
# {"timestamp": "2026-05-14T00:25:05.820777Z", "level": "info", "event": "request_completed", "method": "DELETE", "path": "/api/models/delete-cached", "status_code": 200, "process_time_ms": 1688.61}
# {"timestamp": "2026-05-14T00:25:06.021755Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-gguf", "status_code": 200, "process_time_ms":
z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.22}
# {"timestamp": "2026-05-14T00:26:10.606870Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.09}
# {"timestamp": "2026-05-14T00:26:12.619339Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.11}
# {"timestamp": "2026-05-14T00:26:14.623137Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.1}
# {"timestamp": "2026-05-14T00:26:16.609438Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.1}
# {"timestamp": "2026-05-14T00:26:18.607879Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.11}
# {"timestamp": "2026-05-14T00:26:20.602664Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.1}
# {"timestamp": "2026-05-14T00:26:22.601725Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.17}
# {"timestamp": "2026-05-14T00:26:23.636337Z", "level": "info", "event": "GGUF downloaded in 44.2s: /root/.cache/huggingface/hub/models--unsloth--gemma-4-26B-A4B-it-GGUF/snapshots/3365c68df1a83799b846d05324ebfadbb8cc70b3/gemma-4-26B-A4B-it-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-05-14T00:26:23.731585Z", "level": "info", "event": "Downloading mmproj: unsloth/gemma-4-26B-A4B-it-GGUF/mmproj-F16.gguf"}
# mmproj-F16.gguf:   0%|          | 0.00/1.19G [00:00<?, ?B/s]
# {"timestamp": "2026-05-14T00:26:24.612852Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.11}
# {"timestamp": "2026-05-14T00:26:26.610166Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/load-progress", "status_code": 200, "process_time_ms": 0.8}
# {"timestamp": "2026-05-14T00:26:28.599175Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/load-progress", "status_code": 200, "process_time_ms": 0.8}
# {"timestamp": "2026-05-14T00:26:30.606852Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/load-progress", "status_code": 200, "process_time_ms": 0.82}
# {"timestamp": "2026-05-14T00:26:32.603975Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/load-progress", "status_code": 200, "process_time_ms": 0.8}
# {"timestamp": "2026-05-14T00:26:34.619382Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/load-progress", "status_code": 200, "process_time_ms": 0.82}
# {"timestamp": "2026-05-14T00:26:35.008491Z", "level": "info", "event": "GGUF metadata: context_length=262144"}
# {"timestamp": "2026-05-14T00:26:35.008788Z", "level": "info", "event": "GGUF metadata: chat_template=16934 chars"}
# {"timestamp": "2026-05-14T00:26:35.008971Z", "level": "info", "event": "GGUF metadata: model supports reasoning (enable_thinking)"}
# {"timestamp": "2026-05-14T00:26:35.009136Z", "level": "info", "event": "GGUF metadata: model supports tool calling"}
# {"timestamp": "2026-05-14T00:26:35.021730Z", "level": "info", "event": "GGUF size: 15.8 GB, est. KV cache: 5.4 GB, context: 262144, GPUs free: [(0, 97248)], selected: [0], fit: False"}
# {"timestamp": "2026-05-14T00:26:35.021951Z", "level": "info", "event": "Reasoning model: {'enable_thinking': True} by default"}
# {"timestamp": "2026-05-14T00:26:35.022184Z", "level": "info", "event": "Using mmproj for vision: /root/.cache/huggingface/hub/models--unsloth--gemma-4-26B-A4B-it-GGUF/snapshots/3365c68df1a83799b846d05324ebfadbb8cc70b3/mmproj-F16.gguf"}
# {"timestamp": "2026-05-14T00:26:35.022309Z", "level": "info", "event": "Starting llama-server: /root/.unsloth/llama.cpp/llama-server -m /root/.cache/huggingface/hub/models--unsloth--gemma-4-26B-A4B-it-GGUF/snapshots/3365c68df1a83799b846d05324ebfadbb8cc70b3/gemma-4-26B-A4B-it-UD-Q4_K_XL.gguf --port 32887 -c 262144 --parallel 1 --flash-attn on --no-context-shift -ngl -1 --threads -1 --jinja --chat-template-kwargs {\"enable_thinking\": true} --mmproj /root/.cache/huggingface/hub/models--unsloth--gemma-4-26B-A4B-it-GGUF/snapshots/3365c68df1a83799b846d05324ebfadbb8cc70b3/mmproj-F16.gguf"}
# {"timestamp": "2026-05-14T00:26:36.604442Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/load-progress", "status_code": 200, "process_time_ms": 0.95}
# {"timestamp": "2026-05-14T00:26:37.970122Z", "level": "info", "event": "llama-server ready on port 32887 for model 'unsloth/gemma-4-26B-A4B-it-GGUF'"}
# {"timestamp": "2026-05-14T00:26:37.970691Z", "level": "info", "event": "Loaded GGUF model via llama-server: unsloth/gemma-4-26B-A4B-it-GGUF"}
# {"timestamp": "2026-05-14T00:26:37.993808Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-05-14T00:26:37.995827Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/load", "status_code": 200, "process_time_ms": 58980.23}
# {"timestamp": "2026-05-14T00:26:38.212004Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 3.07}
# {"timestamp": "2026-05-14T00:26:38.215373Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-05-14T00:26:38.217466Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 4.47}
# {"timestamp": "2026-05-14T00:26:38.218720Z", "level": "info", "event": "Found 0 trained models in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-05-14T00:26:38.219061Z", "level": "info", "event": "Found 0 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-05-14T00:26:38.219412Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 1.39}
# ={"timestamp": "2026-05-14T00:33:10.234163Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 0.87}
# {"timestamp": "2026-05-14T00:33:14.153262Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/v1/chat/completions", "status_code": 200, "process_time_ms": 1.15}
# ={"timestamp": "2026-05-14T00:33:22.753238Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/script.js", "status_code": 200, "process_time_ms": 1.26}
# {"timestamp": "2026-05-14T00:33:22.753771Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/style.css", "status_code": 200, "process_time_ms": 1.8}
# {"timestamp": "2026-05-14T00:33:48.710963Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 0.76}
# {"timestamp": "2026-05-14T00:34:09.847101Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/v1/chat/completions", "status_code": 200, "process_time_ms": 1.55}
# {"timestamp": "2026-05-14T00:35:29.900228Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/v1/chat/completions", "status_code": 200, "process_time_ms": 1.55}
# {"timestamp": "2026-05-14T00:37:27.463171Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 0.88}
# {"timestamp": "2026-05-14T00:37:30.581046Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/v1/chat/completions", "status_code": 200, "process_time_ms": 1.59}
# ={"timestamp": "2026-05-14T00:41:15.493543Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-models", "status_code": 200, "process_time_ms": 3.02}
# {"timestamp": "2026-05-14T00:41:15.494524Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 2.27}
# {"timestamp": "2026-05-14T00:41:15.497478Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-gguf", "status_code": 200, "process_time_ms": 2.41}
# {"timestamp": "2026-05-14T00:41:15.497735Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/recommended-folders", "status_code": 200, "process_time_ms": 2.61}
# {"timestamp": "2026-05-14T00:41:15.498927Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/scan-folders", "status_code": 200, "process_time_ms": 1.53}
# {"timestamp": "2026-05-14T00:41:17.078664Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-variants", "status_code": 200, "process_time_ms": 138.88}
# {"timestamp": "2026-05-14T00:41:19.410776Z", "level": "info", "event": "request_completed", "method": "DELETE", "path": "/api/models/delete-cached", "status_code": 400, "process_time_ms": 1.06}
# {"timestamp": "2026-05-14T00:41:22.811445Z", "level": "info", "event": "request_completed", "method": "DELETE", "path": "/api/models/delete-cached", "status_code": 400, "process_time_ms": 1.04}
# {"timestamp": "2026-05-14T00:41:24.984655Z", "level": "info", "event": "Unloaded GGUF model: unsloth/gemma-4-26B-A4B-it-GGUF"}
# {"timestamp": "2026-05-14T00:41:24.984984Z", "level": "info", "event": "Unloaded GGUF model: unsloth/gemma-4-26B-A4B-it-GGUF"}
# {"timestamp": "2026-05-14T00:41:24.985321Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/unload", "status_code": 200, "process_time_ms": 315.43}
# {"timestamp": "2026-05-14T00:41:25.177565Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 0.55}
# {"timestamp": "2026-05-14T00:41:25.180467Z", "level": "info", "event": "Found 0 trained models in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-05-14T00:41:25.180820Z", "level": "info", "event": "Found 0 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-05-14T00:41:25.181085Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 1.29}
# {"timestamp": "2026-05-14T00:41:25.184227Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 1.58}
# {"timestamp": "2026-05-14T00:41:45.500554Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 1.66}
# {"timestamp": "2026-05-14T00:41:45.503950Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-gguf", "status_code": 200, "process_time_ms": 2.34}
# {"timestamp": "2026-05-14T00:41:45.504314Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/scan-folders", "status_code": 200, "process_time_ms": 2.68}
# {"timestamp": "2026-05-14T00:41:45.506480Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/recommended-folders", "status_code": 200, "process_time_ms": 2.64}
# {"timestamp": "2026-05-14T00:41:45.506708Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-models", "status_code": 200, "process_time_ms": 2.81}
# {"timestamp": "2026-05-14T00:41:47.934928Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-variants", "status_code": 200, "process_time_ms": 125.42}
# {"timestamp": "2026-05-14T00:41:51.475856Z", "level": "info", "event": "Deleted 1 file(s) for unsloth/gemma-4-26B-A4B-it-GGUF variant UD-Q4_K_XL: 16222.9 MB freed"}
# {"timestamp": "2026-05-14T00:41:51.476653Z", "level": "info", "event": "request_completed", "method": "DELETE", "path": "/api/models/delete-cached", "status_code": 200, "process_time_ms": 1146.52}
# {"timestamp": "2026-05-14T00:41:51.667539Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-gguf", "status_code": 200, "process_time_ms": 1.58}
# {"timestamp": "2026-05-14T00:41:51.671473Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 1.51}
# {"timestamp": "2026-05-14T00:41:51.674669Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-models", "status_code": 200, "process_time_ms": 1.17}
# {"timestamp": "2026-05-14T00:41:51.970560Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-variants", "status_code": 200, "process_time_ms": 110.52}
# {"timestamp": "2026-05-14T00:42:01.310187Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-variants", "status_code": 200, "process_time_ms": 106.2}
# {"timestamp": "2026-05-14T00:42:03.812297Z", "level": "info", "event": "Detected remote GGUF repo 'unsloth/Qwen3.6-35B-A3B-GGUF', variant=BF16, vision=True"}
# {"timestamp": "2026-05-14T00:42:03.814706Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-05-14T00:42:03.816688Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/validate", "status_code": 200, "process_time_ms": 217.1}
# {"timestamp": "2026-05-14T00:42:04.090613Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.09}
# {"timestamp": "2026-05-14T00:42:10.801436Z", "level": "info", "event": "Detected remote GGUF repo 'unsloth/Qwen3.6-35B-A3B-GGUF', variant=BF16, vision=True"}
# {"timestamp": "2026-05-14T00:42:10.801863Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 224.4}
# {"timestamp": "2026-05-14T00:42:10.988527Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 0.74}
# {"timestamp": "2026-05-14T00:42:11.038061Z", "level": "info", "event": "GGUF download: 64.6 GB needed (0.0 GB already cached), 186.9 GB free on disk"}
# {"timestamp": "2026-05-14T00:42:11.038318Z", "level": "info", "event": "Resolving GGUF: unsloth/Qwen3.6-35B-A3B-GGUF/BF16/Qwen3.6-35B-A3B-BF16-00001-of-00002.gguf (+1 shards)"}
# {"timestamp": "2026-05-14T00:42:11.174405Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.04}
# BF16/Qwen3.6-35B-A3B-BF16-00001-of-00002(…):   0%|          | 0.00/49.9G [00:00<?, ?B/s]
# {"timestamp": "2026-05-14T00:42:11.607384Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 0.96}
# {"timestamp": "2026-05-14T00:42:13.655852Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.83}
# ...
# {"timestamp": "2026-05-14T00:44:37.585343Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.16}
# {"timestamp": "2026-05-14T00:44:39.584676Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.22}
# {"timestamp": "2026-05-14T00:44:41.604449Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.19}
# {"timestamp": "2026-05-14T00:44:43.604326Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.16}
# {"timestamp": "2026-05-14T00:44:45.603305Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.13}
# {"timestamp": "2026-05-14T00:44:51.702325Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.14}
# {"timestamp": "2026-05-14T00:44:51.888522Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.14}
# {"timestamp": "2026-05-14T00:44:52.076417Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 0.86}
# {"timestamp": "2026-05-14T00:44:53.590074Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.15}
# {"timestamp": "2026-05-14T00:44:55.608644Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.13}
# {"timestamp": "2026-05-14T00:44:57.593015Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.11}
# {"timestamp": "2026-05-14T00:44:59.595166Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.43}
# {"timestamp": "2026-05-14T00:45:01.589868Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.22}
# {"timestamp": "2026-05-14T00:45:03.612101Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.29}
# {"timestamp": "2026-05-14T00:45:05.588679Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.34}
# {"timestamp": "2026-05-14T00:45:07.593622Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.18}
# {"timestamp": "2026-05-14T00:45:09.588426Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.16}
# {"timestamp": "2026-05-14T00:45:11.596946Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.16}
# {"timestamp": "2026-05-14T00:45:13.614778Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.16}
# {"timestamp": "2026-05-14T00:45:15.605899Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.14}
# {"timestamp": "2026-05-14T00:45:17.592225Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.17}
# {"timestamp": "2026-05-14T00:45:19.599109Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.18}
# {"timestamp": "2026-05-14T00:45:21.598046Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.11}
# {"timestamp": "2026-05-14T00:45:23.605580Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.45}
# {"timestamp": "2026-05-14T00:45:25.606587Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.08}
# {"timestamp": "2026-05-14T00:45:27.586316Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.11}
# {"timestamp": "2026-05-14T00:45:29.587345Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.12}
# {"timestamp": "2026-05-14T00:45:30.852228Z", "level": "info", "event": "GGUF downloaded in 199.8s: /root/.cache/huggingface/hub/models--unsloth--Qwen3.6-35B-A3B-GGUF/snapshots/a483e9e6cbd595906af30beda3187c2663a1118c/BF16/Qwen3.6-35B-A3B-BF16-00001-of-00002.gguf"}
# {"timestamp": "2026-05-14T00:45:30.951353Z", "level": "info", "event": "Downloading mmproj: unsloth/Qwen3.6-35B-A3B-GGUF/mmproj-F16.gguf"}
# {"timestamp": "2026-05-14T00:45:31.110448Z", "level": "info", "event": "GGUF metadata: context_length=262144"}
# {"timestamp": "2026-05-14T00:45:31.110890Z", "level": "info", "event": "GGUF metadata: chat_template=8057 chars"}
# {"timestamp": "2026-05-14T00:45:31.111121Z", "level": "info", "event": "GGUF metadata: model supports reasoning (enable_thinking)"}
# {"timestamp": "2026-05-14T00:45:31.111296Z", "level": "info", "event": "GGUF metadata: model supports preserve_thinking"}
# {"timestamp": "2026-05-14T00:45:31.111478Z", "level": "info", "event": "GGUF metadata: model supports tool calling"}
# {"timestamp": "2026-05-14T00:45:31.197862Z", "level": "info", "event": "GGUF size: 64.6 GB, est. KV cache: 5.0 GB, context: 262144, GPUs free: [(0, 97248)], selected: [0], fit: False"}
# {"timestamp": "2026-05-14T00:45:31.198245Z", "level": "info", "event": "Reasoning model: {'enable_thinking': False} by default"}
# {"timestamp": "2026-05-14T00:45:31.198549Z", "level": "info", "event": "Using mmproj for vision: /root/.cache/huggingface/hub/models--unsloth--Qwen3.6-35B-A3B-GGUF/snapshots/a483e9e6cbd595906af30beda3187c2663a1118c/mmproj-F16.gguf"}
# {"timestamp": "2026-05-14T00:45:31.198739Z", "level": "info", "event": "Starting llama-server: /root/.unsloth/llama.cpp/llama-server -m /root/.cache/huggingface/hub/models--unsloth--Qwen3.6-35B-A3B-GGUF/snapshots/a483e9e6cbd595906af30beda3187c2663a1118c/BF16/Qwen3.6-35B-A3B-BF16-00001-of-00002.gguf --port 37593 -c 262144 --parallel 1 --flash-attn on --no-context-shift -ngl -1 --threads -1 --jinja --chat-template-kwargs {\"enable_thinking\": false} --mmproj /root/.cache/huggingface/hub/models--unsloth--Qwen3.6-35B-A3B-GGUF/snapshots/a483e9e6cbd595906af30beda3187c2663a1118c/mmproj-F16.gguf"}
# {"timestamp": "2026-05-14T00:45:31.586759Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-download-progress", "status_code": 200, "process_time_ms": 1.13}
# {"timestamp": "2026-05-14T00:45:33.607746Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/load-progress", "status_code": 200, "process_time_ms": 0.96}
# {"timestamp": "2026-05-14T00:45:35.610043Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/load-progress", "status_code": 200, "process_time_ms": 1.0}
# {"timestamp": "2026-05-14T00:45:37.586746Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/load-progress", "status_code": 200, "process_time_ms": 1.02}
# {"timestamp": "2026-05-14T00:45:39.588915Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/load-progress", "status_code": 200, "process_time_ms": 4.13}
# {"timestamp": "2026-05-14T00:45:41.178288Z", "level": "info", "event": "llama-server ready on port 37593 for model 'unsloth/Qwen3.6-35B-A3B-GGUF'"}
# {"timestamp": "2026-05-14T00:45:41.178805Z", "level": "info", "event": "Loaded GGUF model via llama-server: unsloth/Qwen3.6-35B-A3B-GGUF"}
# {"timestamp": "2026-05-14T00:45:41.199647Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-05-14T00:45:41.201632Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/load", "status_code": 200, "process_time_ms": 210624.56}
# {"timestamp": "2026-05-14T00:45:41.392074Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 2.0}
# {"timestamp": "2026-05-14T00:45:41.398457Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-05-14T00:45:41.400467Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 4.15}
# {"timestamp": "2026-05-14T00:45:41.401755Z", "level": "info", "event": "Found 0 trained models in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-05-14T00:45:41.402091Z", "level": "info", "event": "Found 0 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-05-14T00:45:41.402443Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 1.4}
# {"timestamp": "2026-05-14T00:45:41.585516Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/load-progress", "status_code": 200, "process_time_ms": 0.62}
# ={"timestamp": "2026-05-14T00:52:54.437640Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 0.9}
# {"timestamp": "2026-05-14T00:53:03.553105Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/v1/chat/completions", "status_code": 200, "process_time_ms": 1.27}
# {"timestamp": "2026-05-14T00:53:08.606393Z", "level": "info", "event": "Re-prompt 1/3: model responded without calling tools (141 chars)"}
# {"timestamp": "2026-05-14T00:53:09.998319Z", "level": "info", "event": "Parsed 1 tool call(s) from structured delta"}
# {"timestamp": "2026-05-14T00:53:09.999658Z", "level": "info", "event": "execute_tool: name=terminal, session_id=None, timeout=300"}
# {"timestamp": "2026-05-14T00:53:10.924598Z", "level": "info", "event": "Parsed 1 tool call(s) from structured delta"}
# {"timestamp": "2026-05-14T00:53:10.925910Z", "level": "info", "event": "execute_tool: name=web_search, session_id=None, timeout=300"}
# {"timestamp": "2026-05-14T00:53:14.038934Z", "level": "info", "event": "Parsed 1 tool call(s) from structured delta"}
# {"timestamp": "2026-05-14T00:53:14.040348Z", "level": "info", "event": "execute_tool: name=terminal, session_id=None, timeout=300"}
# {"timestamp": "2026-05-14T00:53:14.990134Z", "level": "info", "event": "Parsed 1 tool call(s) from structured delta"}
# {"timestamp": "2026-05-14T00:53:14.991246Z", "level": "info", "event": "execute_tool: name=terminal, session_id=None, timeout=300"}
# {"timestamp": "2026-05-14T00:53:16.126235Z", "level": "info", "event": "Parsed 1 tool call(s) from structured delta"}
# {"timestamp": "2026-05-14T00:53:16.127585Z", "level": "info", "event": "execute_tool: name=terminal, session_id=None, timeout=300"}
# ={"timestamp": "2026-05-14T00:53:19.370324Z", "level": "info", "event": "Parsed 1 tool call(s) from structured delta"}
# {"timestamp": "2026-05-14T00:53:19.371557Z", "level": "info", "event": "execute_tool: name=terminal, session_id=None, timeout=300"}
# {"timestamp": "2026-05-14T00:53:21.065494Z", "level": "info", "event": "Parsed 1 tool call(s) from structured delta"}
# {"timestamp": "2026-05-14T00:53:21.066746Z", "level": "info", "event": "execute_tool: name=terminal, session_id=None, timeout=300"}
# {"timestamp": "2026-05-14T00:53:23.262702Z", "level": "info", "event": "Parsed 1 tool call(s) from structured delta"}
# {"timestamp": "2026-05-14T00:53:23.264165Z", "level": "info", "event": "execute_tool: name=terminal, session_id=None, timeout=300"}
# {"timestamp": "2026-05-14T00:53:47.424878Z", "level": "info", "event": "Parsed 1 tool call(s) from structured delta"}
# {"timestamp": "2026-05-14T00:53:47.426048Z", "level": "info", "event": "execute_tool: name=terminal, session_id=None, timeout=300"}
# {"timestamp": "2026-05-14T00:53:49.284007Z", "level": "info", "event": "Re-prompt 2/3: model responded without calling tools (109 chars)"}
# ={"timestamp": "2026-05-14T00:58:21.337253Z", "level": "info", "event": "Parsed 1 tool call(s) from structured delta"}
# {"timestamp": "2026-05-14T00:58:21.339726Z", "level": "info", "event": "execute_tool: name=python, session_id=None, timeout=300"}
# {"timestamp": "2026-05-14T00:58:37.095436Z", "level": "info", "event": "Parsed 1 tool call(s) from structured delta"}
# {"timestamp": "2026-05-14T00:58:37.098092Z", "level": "info", "event": "execute_tool: name=python, session_id=None, timeout=300"}
# {"timestamp": "2026-05-14T00:58:41.997371Z", "level": "info", "event": "Parsed 1 tool call(s) from structured delta"}
# {"timestamp": "2026-05-14T00:58:41.999027Z", "level": "info", "event": "execute_tool: name=python, session_id=None, timeout=300"}
# {"timestamp": "2026-05-14T00:58:44.418791Z", "level": "info", "event": "Parsed 1 tool call(s) from structured delta"}
# {"timestamp": "2026-05-14T00:58:44.420324Z", "level": "info", "event": "execute_tool: name=python, session_id=None, timeout=300"}
# {"timestamp": "2026-05-14T00:58:46.458066Z", "level": "info", "event": "Parsed 1 tool call(s) from structured delta"}
# {"timestamp": "2026-05-14T00:58:46.459471Z", "level": "info", "event": "execute_tool: name=python, session_id=None, timeout=300"}
# {"timestamp": "2026-05-14T00:58:54.867197Z", "level": "info", "event": "Parsed 1 tool call(s) from structured delta"}
# {"timestamp": "2026-05-14T00:58:54.869837Z", "level": "info", "event": "execute_tool: name=python, session_id=None, timeout=300"}
# {"timestamp": "2026-05-14T00:59:01.437931Z", "level": "info", "event": "Parsed 1 tool call(s) from structured delta"}
# {"timestamp": "2026-05-14T00:59:01.439521Z", "level": "info", "event": "execute_tool: name=python, session_id=None, timeout=300"}
# {"timestamp": "2026-05-14T00:59:04.334147Z", "level": "info", "event": "Parsed 1 tool call(s) from structured delta"}
# {"timestamp": "2026-05-14T00:59:04.335720Z", "level": "info", "event": "execute_tool: name=python, session_id=None, timeout=300"}
# ========================================================================================================================================================{"timestamp": "2026-05-14T13:39:27.385453Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 0.95}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1096/3552804093.py in <cell line: 0>()
#       1 from google.colab import output
#       2 output.serve_kernel_port_as_iframe(8888, height = 1200, width = "100%")
# ----> 3 for _ in range(10000): time.sleep(300), print("=", end = "")
#
# KeyboardInterrupt:

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other resources:
# 1. Looking to use Unsloth locally? Read our [Installation Guide](https://unsloth.ai/docs/get-started/install) for details on installing Unsloth on Windows, Docker, AMD, Intel GPUs.
# 2. Learn how to do Reinforcement Learning with our [RL Guide and notebooks](https://unsloth.ai/docs/get-started/reinforcement-learning-rl-guide).
# 3. Read our guides and notebooks for [Text-to-speech (TTS)](https://unsloth.ai/docs/basics/text-to-speech-tts-fine-tuning) and [vision](https://unsloth.ai/docs/basics/vision-fine-tuning) model support.
# 4. Explore our [LLM Tutorials Directory](https://unsloth.ai/docs/models/tutorials-how-to-fine-tune-and-run-llms) to find dedicated guides for each model.
# 5. Need help with Inference? Read our [Inference & Deployment page](https://unsloth.ai/docs/basics/inference-and-deployment) for details on using vLLM, llama.cpp, Ollama etc.
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
#
#   <b>This notebook is licensed <a href="https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0">AGPL-3.0</a></b>
# </div>
